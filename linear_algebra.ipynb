# %%
import numpy as np
import math

# %%
v = np.array([3, 2])
w = np.array([1, 4])

# %%
print(v+w)
# Out:
# [4 6]

# %%
print(2 * v)
# Out:
# [6 4]

# %%
print(round(np.linalg.norm(v), 4))
# Out:
# 3.6056

# %%
print(v/np.linalg.norm(v))
# Out:
# [0.83205029 0.5547002 ]
